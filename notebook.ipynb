# %%
import nesspy_analysis as npa
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
fig, ax = plt.subplots(figsize=(8, 6))

base_path = Path("/Volumes/2025/scheme7/SL_F0_SCHEME_7_D0_K1_GROWTH")
analysis = npa.DynamicalOrderDisorder("dmu0", base_path)
analysis.analysis(bootstrap=True, n_bootstrap=25, type="mu", n_samples=8)
results_fit_mu = analysis.mu_fit_results
analysis.analysis(bootstrap=False, type="full")

ax2 = ax.twinx()
ax.plot(
    results_fit_mu["mu_cont"],
    results_fit_mu["lorentzian_fit"],
)
ax2.scatter(
    analysis.data["mu"],
    analysis.data["m"],
)

base_path = Path("/Volumes/2025/scheme7/SL_F0_SCHEME_7_D1_K1_GROWTH")
analysis = npa.DynamicalOrderDisorder("dmu1", base_path)
analysis.analysis(bootstrap=True, n_bootstrap=25, type="mu", n_samples=8)
results_fit_mu = analysis.mu_fit_results
analysis.analysis(bootstrap=False, type="full")

ax.plot(
    results_fit_mu["mu_cont"],
    results_fit_mu["lorentzian_fit"],
)
ax2.scatter(
    analysis.data["mu"],
    analysis.data["m"],
)

base_path = Path("/Volumes/2025/scheme7/SL_F0_SCHEME_7_D2_K1_GROWTH")
analysis = npa.DynamicalOrderDisorder("dmu2", base_path)
analysis.analysis(bootstrap=True, n_bootstrap=25, type="mu", n_samples=8)
results_fit_mu = analysis.mu_fit_results
analysis.analysis(bootstrap=False, type="full")

ax.plot(
    results_fit_mu["mu_cont"],
    results_fit_mu["lorentzian_fit"],
)
ax2.scatter(
    analysis.data["mu"],
    analysis.data["m"],
)

base_path = Path("/Volumes/2025/scheme7/SL_F0_SCHEME_7_D6_K1_GROWTH")
analysis = npa.DynamicalOrderDisorder("dmu6", base_path)
analysis.analysis(bootstrap=True, n_bootstrap=25, type="mu", n_samples=8)
results_fit_mu = analysis.mu_fit_results
analysis.analysis(bootstrap=False, type="full")

ax.plot(
    results_fit_mu["mu_cont"],
    results_fit_mu["lorentzian_fit"],
)
ax2.scatter(
    analysis.data["mu"],
    analysis.data["m"],
)
# Out:
# /Users/moritzobenauer/Projects/nesspy_analysis/src/nesspy_analysis/fitting.py:79: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(lorentzian, xdata, ydata, p0=[x0, width, max_val])
# /Users/moritzobenauer/Projects/nesspy_analysis/src/nesspy_analysis/fitting.py:79: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(lorentzian, xdata, ydata, p0=[x0, width, max_val])
# /Users/moritzobenauer/Projects/nesspy_analysis/src/nesspy_analysis/fitting.py:79: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(lorentzian, xdata, ydata, p0=[x0, width, max_val])
# /Users/moritzobenauer/Projects/nesspy_analysis/src/nesspy_analysis/fitting.py:79: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(lorentzian, xdata, ydata, p0=[x0, width, max_val])
# ...

# %%
fig, ax = plt.subplots(figsize=(8, 6))

base_path = Path("/Volumes/2025/scheme7/SL_F0_SCHEME_7_D0_K1_GROWTH")
analysis_2 = npa.DynamicalOrderDisorder("dmu0", base_path)
analysis_2.analysis(bootstrap=True, n_bootstrap=5, type="growth_speed", n_samples=8)
results_fit_speed = analysis_2.growth_speed_fit_results
analysis_2.analysis(bootstrap=False, type="full")

mu_discrete = analysis_2.data["mu"]
m_discrete = analysis_2.data["m"]

analysis_2.analysis(bootstrap=True, n_bootstrap=5, type="mu", n_samples=8)

mus = analysis_2.mu_fit_results["mu_cont"]


thermo = npa.Thermos(jhom=-3.5, jhet=-2.0, beta=1.0, fres=0.0, k=1.0, dmu=0.0)

dphis = npa.calculate_dphi(mus, thermo, drivetype="NODRIVE")
dphis_discrete = npa.calculate_dphi(mu_discrete, thermo, drivetype="NODRIVE")

# ax.plot(dphis, results_fit_speed["lorentzian_fit"], label="Lorentzian Fit vs dphi")
ax.plot(dphis_discrete, m_discrete, label="Data vs dphi")


base_path = Path("/Volumes/2025/scheme7/SL_F0_SCHEME_7_D1_K1_GROWTH")
analysis_2 = npa.DynamicalOrderDisorder("dmu1", base_path)
analysis_2.analysis(bootstrap=True, n_bootstrap=5, type="growth_speed", n_samples=8)
results_fit_speed = analysis_2.growth_speed_fit_results
analysis_2.analysis(bootstrap=False, type="full")

mu_discrete = analysis_2.data["mu"]
m_discrete = analysis_2.data["m"]

analysis_2.analysis(bootstrap=True, n_bootstrap=5, type="mu", n_samples=8)

mus = analysis_2.mu_fit_results["mu_cont"]


thermo = npa.Thermos(jhom=-3.5, jhet=-2.0, beta=1.0, fres=0.0, k=1.0, dmu=1.0)

dphis = npa.calculate_dphi(mus, thermo, drivetype="SCHEME_7")
dphis_discrete = npa.calculate_dphi(mu_discrete, thermo, drivetype="SCHEME_7")
ax.plot(dphis_discrete, m_discrete, label="Data vs dphi")


base_path = Path("/Volumes/2025/scheme7/SL_F0_SCHEME_7_D2_K1_GROWTH")
analysis_2 = npa.DynamicalOrderDisorder("dmu2", base_path)
analysis_2.analysis(bootstrap=True, n_bootstrap=5, type="growth_speed", n_samples=8)
results_fit_speed = analysis_2.growth_speed_fit_results
analysis_2.analysis(bootstrap=False, type="full")

mu_discrete = analysis_2.data["mu"]
m_discrete = analysis_2.data["m"]

analysis_2.analysis(bootstrap=True, n_bootstrap=5, type="mu", n_samples=8)

mus = analysis_2.mu_fit_results["mu_cont"]


thermo = npa.Thermos(jhom=-3.5, jhet=-2.0, beta=1.0, fres=0.0, k=1.0, dmu=2.0)

dphis = npa.calculate_dphi(mus, thermo, drivetype="SCHEME_7")
dphis_discrete = npa.calculate_dphi(mu_discrete, thermo, drivetype="SCHEME_7")
ax.plot(dphis_discrete, m_discrete, label="Data vs dphi")

base_path = Path("/Volumes/2025/scheme7/SL_F0_SCHEME_7_D6_K1_GROWTH")
analysis_2 = npa.DynamicalOrderDisorder("dmu6", base_path)
analysis_2.analysis(bootstrap=True, n_bootstrap=5, type="growth_speed", n_samples=8)
results_fit_speed = analysis_2.growth_speed_fit_results
analysis_2.analysis(bootstrap=False, type="full")

mu_discrete = analysis_2.data["mu"]
m_discrete = analysis_2.data["m"]

analysis_2.analysis(bootstrap=True, n_bootstrap=5, type="mu", n_samples=8)

mus = analysis_2.mu_fit_results["mu_cont"]


thermo = npa.Thermos(jhom=-3.5, jhet=-2.0, beta=1.0, fres=0.0, k=1.0, dmu=6.0)

dphis = npa.calculate_dphi(mus, thermo, drivetype="SCHEME_7")
dphis_discrete = npa.calculate_dphi(mu_discrete, thermo, drivetype="SCHEME_7")
ax.plot(dphis_discrete, m_discrete, label="Data vs dphi")
# Out:
# /Users/moritzobenauer/Projects/nesspy_analysis/src/nesspy_analysis/fitting.py:79: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(lorentzian, xdata, ydata, p0=[x0, width, max_val])
# /Users/moritzobenauer/Projects/nesspy_analysis/src/nesspy_analysis/fitting.py:79: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(lorentzian, xdata, ydata, p0=[x0, width, max_val])

# %%
fig, ax = plt.subplots(figsize=(8, 6))
ax.set_title(r"Scheme 6 $\Delta \mu = \Delta \mu \exp(-\mathcal{N})$")

base_path = Path("/Volumes/2025/research_nov_2025_data/SL_F0_SCHEME_6_D1_K1_GROWTH")
analysis_2 = npa.DynamicalOrderDisorder("dmu1", base_path)
analysis_2.analysis(bootstrap=True, n_bootstrap=5, type="growth_speed", n_samples=8)
results_fit_speed = analysis_2.growth_speed_fit_results
analysis_2.analysis(bootstrap=False, type="full")
mu_discrete = analysis_2.data["mu"]
m_discrete = analysis_2.data["m"]
analysis_2.analysis(bootstrap=True, n_bootstrap=5, type="mu", n_samples=8)
mus = analysis_2.mu_fit_results["mu_cont"]
thermo = npa.Thermos(jhom=-3.5, jhet=-2.0, beta=1.0, fres=0.0, k=1.0, dmu=1.0)

dphis = npa.calculate_dphi(mus, thermo, drivetype="SCHEME_6")
dphis_discrete = npa.calculate_dphi(mu_discrete, thermo, drivetype="SCHEME_6")
ax.plot(dphis_discrete, m_discrete, label="dmu1", ls="--", ms=5, marker="o")

base_path = Path("/Volumes/2025/research_nov_2025_data/SL_F0_SCHEME_6_D2_K1_GROWTH")
analysis_2 = npa.DynamicalOrderDisorder("dmu2", base_path)
analysis_2.analysis(bootstrap=True, n_bootstrap=5, type="growth_speed", n_samples=8)
results_fit_speed = analysis_2.growth_speed_fit_results
analysis_2.analysis(bootstrap=False, type="full")
mu_discrete = analysis_2.data["mu"]
m_discrete = analysis_2.data["m"]
analysis_2.analysis(bootstrap=True, n_bootstrap=5, type="mu", n_samples=8)
mus = analysis_2.mu_fit_results["mu_cont"]
thermo = npa.Thermos(jhom=-3.5, jhet=-2.0, beta=1.0, fres=0.0, k=1.0, dmu=2.0)

dphis = npa.calculate_dphi(mus, thermo, drivetype="SCHEME_6")
dphis_discrete = npa.calculate_dphi(mu_discrete, thermo, drivetype="SCHEME_6")
ax.plot(dphis_discrete, m_discrete, label="dmu2", ls="--", ms=5, marker="o")

base_path = Path("/Volumes/2025/research_nov_2025_data/SL_F0_SCHEME_6_D3_K1_GROWTH")
analysis_2 = npa.DynamicalOrderDisorder("dmu3", base_path)
analysis_2.analysis(bootstrap=True, n_bootstrap=5, type="growth_speed", n_samples=8)
results_fit_speed = analysis_2.growth_speed_fit_results
analysis_2.analysis(bootstrap=False, type="full")
mu_discrete = analysis_2.data["mu"]
m_discrete = analysis_2.data["m"]
analysis_2.analysis(bootstrap=True, n_bootstrap=5, type="mu", n_samples=8)
mus = analysis_2.mu_fit_results["mu_cont"]
thermo = npa.Thermos(jhom=-3.5, jhet=-2.0, beta=1.0, fres=0.0, k=1.0, dmu=3.0)

dphis = npa.calculate_dphi(mus, thermo, drivetype="SCHEME_6")
dphis_discrete = npa.calculate_dphi(mu_discrete, thermo, drivetype="SCHEME_6")
ax.plot(dphis_discrete, m_discrete, label="dmu3", ls="--", ms=5, marker="o")

base_path = Path("/Volumes/2025/research_nov_2025_data/SL_F0_SCHEME_6_D4_K1_GROWTH")
analysis_2 = npa.DynamicalOrderDisorder("dmu4", base_path)
analysis_2.analysis(bootstrap=True, n_bootstrap=5, type="growth_speed", n_samples=8)
results_fit_speed = analysis_2.growth_speed_fit_results
analysis_2.analysis(bootstrap=False, type="full")
mu_discrete = analysis_2.data["mu"]
m_discrete = analysis_2.data["m"]
analysis_2.analysis(bootstrap=True, n_bootstrap=5, type="mu", n_samples=8)
mus = analysis_2.mu_fit_results["mu_cont"]
thermo = npa.Thermos(jhom=-3.5, jhet=-2.0, beta=1.0, fres=0.0, k=1.0, dmu=4.0)

dphis = npa.calculate_dphi(mus, thermo, drivetype="SCHEME_6")
dphis_discrete = npa.calculate_dphi(mu_discrete, thermo, drivetype="SCHEME_6")
ax.plot(dphis_discrete, m_discrete, label="dmu4", ls="--", ms=5, marker="o")

plt.legend()
# Out:
# /Users/moritzobenauer/Projects/nesspy_analysis/src/nesspy_analysis/fitting.py:79: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(lorentzian, xdata, ydata, p0=[x0, width, max_val])
# /Users/moritzobenauer/Projects/nesspy_analysis/src/nesspy_analysis/fitting.py:79: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(lorentzian, xdata, ydata, p0=[x0, width, max_val])
# /Users/moritzobenauer/Projects/nesspy_analysis/src/nesspy_analysis/fitting.py:79: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(lorentzian, xdata, ydata, p0=[x0, width, max_val])
# /Users/moritzobenauer/Projects/nesspy_analysis/src/nesspy_analysis/fitting.py:79: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(lorentzian, xdata, ydata, p0=[x0, width, max_val])
# ...

# %%
import nesspy_analysis as npa
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots(figsize=(8, 6))
ax.set_title(r"Scheme 6 $\Delta \mu = \Delta \mu \exp(-\mathcal{N})$")

base_path = Path("/Volumes/2025/research_nov_2025_data/SL_F0_SCHEME_6_D1_K1_GROWTH")
analysis_2 = npa.DynamicalOrderDisorder("dmu1", base_path)
analysis_2.analysis(bootstrap=True, n_bootstrap=5, type="growth_speed", n_samples=8)

results_fit_speed = analysis_2.growth_speed_fit_results
analysis_2.analysis(bootstrap=False, type="full")
mu_discrete = analysis_2.data["mu"]
m_discrete = analysis_2.data["m"]
analysis_2.analysis(bootstrap=True, n_bootstrap=5, type="mu", n_samples=8)
mus = analysis_2.mu_fit_results["mu_cont"]

thermo = npa.Thermos(jhom=-3.5, jhet=-2.0, beta=1.0, fres=0.0, k=1.0, dmu=1.0)

dphis = npa.calculate_dphi(mus, thermo, drivetype="SCHEME_6")
fit = analysis_2.mu_fit_results["lorentzian_fit"]
dphis_discrete = npa.calculate_dphi(mu_discrete, thermo, drivetype="SCHEME_6")
ax.plot(
    dphis,
    analysis_2.mu_fit_results["lorentzian_fit"],
    label="dmu1",
    ls="--",
    ms=5,
    marker="o",
)

base_path = Path("/Volumes/2025/research_nov_2025_data/SL_F0_SCHEME_6_D2_K1_GROWTH")
analysis_2 = npa.DynamicalOrderDisorder("dmu2", base_path)
analysis_2.analysis(bootstrap=True, n_bootstrap=4, type="growth_speed", n_samples=4)
results_fit_speed = analysis_2.growth_speed_fit_results
analysis_2.analysis(bootstrap=False, type="full")
mu_discrete = analysis_2.data["mu"]
m_discrete = analysis_2.data["m"]
analysis_2.analysis(bootstrap=True, n_bootstrap=5, type="mu", n_samples=8)
mus = analysis_2.mu_fit_results["mu_cont"]
thermo = npa.Thermos(jhom=-3.5, jhet=-2.0, beta=1.0, fres=0.0, k=1.0, dmu=2.0)

dphis = npa.calculate_dphi(mus, thermo, drivetype="SCHEME_6")
dphis_discrete = npa.calculate_dphi(mu_discrete, thermo, drivetype="SCHEME_6")
ax.plot(
    dphis,
    analysis_2.mu_fit_results["lorentzian_fit"],
    label="dmu2",
    ls="--",
    ms=5,
    marker="o",
)

base_path = Path("/Volumes/2025/research_nov_2025_data/SL_F0_SCHEME_6_D3_K1_GROWTH")
analysis_2 = npa.DynamicalOrderDisorder("dmu3", base_path)
analysis_2.analysis(bootstrap=True, n_bootstrap=4, type="growth_speed", n_samples=4)
results_fit_speed = analysis_2.growth_speed_fit_results
analysis_2.analysis(bootstrap=False, type="full")
mu_discrete = analysis_2.data["mu"]
m_discrete = analysis_2.data["m"]
analysis_2.analysis(bootstrap=True, n_bootstrap=4, type="mu", n_samples=4)
mus = analysis_2.mu_fit_results["mu_cont"]
thermo = npa.Thermos(jhom=-3.5, jhet=-2.0, beta=1.0, fres=0.0, k=1.0, dmu=3.0)

dphis = npa.calculate_dphi(mus, thermo, drivetype="SCHEME_6")
dphis_discrete = npa.calculate_dphi(mu_discrete, thermo, drivetype="SCHEME_6")
ax.plot(
    dphis,
    analysis_2.mu_fit_results["lorentzian_fit"],
    label="dmu3",
    ls="--",
    ms=5,
    marker="o",
)

base_path = Path("/Volumes/2025/research_nov_2025_data/SL_F0_SCHEME_6_D4_K1_GROWTH")
analysis_2 = npa.DynamicalOrderDisorder("dmu4", base_path)
analysis_2.analysis(bootstrap=True, n_bootstrap=5, type="growth_speed", n_samples=5)
results_fit_speed = analysis_2.growth_speed_fit_results
analysis_2.analysis(bootstrap=False, type="full")
mu_discrete = analysis_2.data["mu"]
m_discrete = analysis_2.data["m"]
analysis_2.analysis(bootstrap=True, n_bootstrap=5, type="mu", n_samples=8)
mus = analysis_2.mu_fit_results["mu_cont"]
thermo = npa.Thermos(jhom=-3.5, jhet=-2.0, beta=1.0, fres=0.0, k=1.0, dmu=4.0)

dphis = npa.calculate_dphi(mus, thermo, drivetype="SCHEME_6")
dphis_discrete = npa.calculate_dphi(mu_discrete, thermo, drivetype="SCHEME_6")
ax.plot(
    dphis,
    analysis_2.mu_fit_results["lorentzian_fit"],
    label="dmu4",
    ls="--",
    ms=5,
    marker="o",
)

plt.legend()
# Out:
# Initialized DynamicalOrderDisorder analysis for dmu1
# /Users/moritzobenauer/Projects/nesspy_analysis/src/nesspy_analysis/fitting.py:79: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(lorentzian, xdata, ydata, p0=[x0, width, max_val], maxfev=10000)
# /Users/moritzobenauer/Projects/nesspy_analysis/src/nesspy_analysis/fitting.py:79: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(lorentzian, xdata, ydata, p0=[x0, width, max_val], maxfev=10000)
# Initialized DynamicalOrderDisorder analysis for dmu2
# /Users/moritzobenauer/Projects/nesspy_analysis/src/nesspy_analysis/fitting.py:79: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(lorentzian, xdata, ydata, p0=[x0, width, max_val], maxfev=10000)
# Initialized DynamicalOrderDisorder analysis for dmu3
# Initialized DynamicalOrderDisorder analysis for dmu4

# %%
import nesspy_analysis as npa
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

n_bootstrap = 10
n_samples = 8

fig, ax = plt.subplots(figsize=(8, 6))
ax.set_title(r"Scheme 6 $\Delta \mu = \Delta \mu \exp(-\mathcal{N})$")

base_path = Path("/Volumes/2025/research_nov_2025_data/SL_F0_SCHEME_6_D1_K1_GROWTH")
analysis_2 = npa.DynamicalOrderDisorder("dmu1", base_path)
analysis_2.analysis(
    bootstrap=True, n_bootstrap=n_bootstrap, type="growth_speed", n_samples=n_samples
)

results_fit_speed = analysis_2.growth_speed_fit_results
analysis_2.analysis(bootstrap=False, type="full")
mu_discrete = analysis_2.data["mu"]
m_discrete = analysis_2.data["m"]
analysis_2.analysis(
    bootstrap=True, n_bootstrap=n_bootstrap, type="mu", n_samples=n_samples
)
mus = analysis_2.mu_fit_results["mu_cont"]

thermo = npa.Thermos(jhom=-3.5, jhet=-2.0, beta=1.0, fres=0.0, k=1.0, dmu=1.0)

dphis = npa.calculate_dphi(mus, thermo, drivetype="SCHEME_6")
fit = analysis_2.mu_fit_results["lorentzian_fit"]
dphis_discrete = npa.calculate_dphi(mu_discrete, thermo, drivetype="SCHEME_6")
ax.plot(
    results_fit_speed["growth_speed_cont"],
    results_fit_speed["lorentzian_fit"],
    label="dmu1",
    ls="--",
    ms=5,
    marker="o",
)

base_path = Path("/Volumes/2025/research_nov_2025_data/SL_F0_SCHEME_6_D2_K1_GROWTH")
analysis_2 = npa.DynamicalOrderDisorder("dmu2", base_path)
analysis_2.analysis(
    bootstrap=True, n_bootstrap=n_bootstrap, type="growth_speed", n_samples=n_samples
)
results_fit_speed = analysis_2.growth_speed_fit_results
analysis_2.analysis(bootstrap=False, type="full")
mu_discrete = analysis_2.data["mu"]
m_discrete = analysis_2.data["m"]
analysis_2.analysis(
    bootstrap=True, n_bootstrap=n_bootstrap, type="mu", n_samples=n_samples
)
mus = analysis_2.mu_fit_results["mu_cont"]
thermo = npa.Thermos(jhom=-3.5, jhet=-2.0, beta=1.0, fres=0.0, k=1.0, dmu=2.0)

dphis = npa.calculate_dphi(mus, thermo, drivetype="SCHEME_6")
dphis_discrete = npa.calculate_dphi(mu_discrete, thermo, drivetype="SCHEME_6")
ax.plot(
    results_fit_speed["growth_speed_cont"],
    results_fit_speed["lorentzian_fit"],
    label="dmu2",
    ls="--",
    ms=5,
    marker="o",
)

base_path = Path("/Volumes/2025/research_nov_2025_data/SL_F0_SCHEME_6_D3_K1_GROWTH")
analysis_2 = npa.DynamicalOrderDisorder("dmu3", base_path)
analysis_2.analysis(
    bootstrap=True, n_bootstrap=n_bootstrap, type="growth_speed", n_samples=n_samples
)
results_fit_speed = analysis_2.growth_speed_fit_results
analysis_2.analysis(bootstrap=False, type="full")
mu_discrete = analysis_2.data["mu"]
m_discrete = analysis_2.data["m"]
analysis_2.analysis(
    bootstrap=True, n_bootstrap=n_bootstrap, type="mu", n_samples=n_samples
)
mus = analysis_2.mu_fit_results["mu_cont"]
thermo = npa.Thermos(jhom=-3.5, jhet=-2.0, beta=1.0, fres=0.0, k=1.0, dmu=3.0)

dphis = npa.calculate_dphi(mus, thermo, drivetype="SCHEME_6")
dphis_discrete = npa.calculate_dphi(mu_discrete, thermo, drivetype="SCHEME_6")
ax.plot(
    results_fit_speed["growth_speed_cont"],
    results_fit_speed["lorentzian_fit"],
    label="dmu3",
    ls="--",
    ms=5,
    marker="o",
)

base_path = Path("/Volumes/2025/research_nov_2025_data/SL_F0_SCHEME_6_D4_K1_GROWTH")
analysis_2 = npa.DynamicalOrderDisorder("dmu4", base_path)
analysis_2.analysis(
    bootstrap=True, n_bootstrap=n_bootstrap, type="growth_speed", n_samples=n_samples
)
results_fit_speed = analysis_2.growth_speed_fit_results
analysis_2.analysis(bootstrap=False, type="full")
mu_discrete = analysis_2.data["mu"]
m_discrete = analysis_2.data["m"]
analysis_2.analysis(
    bootstrap=True, n_bootstrap=n_bootstrap, type="mu", n_samples=n_samples
)
mus = analysis_2.mu_fit_results["mu_cont"]
thermo = npa.Thermos(jhom=-3.5, jhet=-2.0, beta=1.0, fres=0.0, k=1.0, dmu=4.0)

dphis = npa.calculate_dphi(mus, thermo, drivetype="SCHEME_6")
dphis_discrete = npa.calculate_dphi(mu_discrete, thermo, drivetype="SCHEME_6")
ax.plot(
    results_fit_speed["growth_speed_cont"],
    results_fit_speed["lorentzian_fit"],
    label="dmu4",
    ls="--",
    ms=5,
    marker="o",
)

plt.legend()
ax.set_xscale("log")
ax.set_yscale("log")
# Out:
# Initialized DynamicalOrderDisorder analysis for dmu1
# /Users/moritzobenauer/Projects/nesspy_analysis/src/nesspy_analysis/fitting.py:79: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(lorentzian, xdata, ydata, p0=[x0, width, max_val], maxfev=10000)
# /Users/moritzobenauer/Projects/nesspy_analysis/src/nesspy_analysis/fitting.py:79: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(lorentzian, xdata, ydata, p0=[x0, width, max_val], maxfev=10000)
# /Users/moritzobenauer/Projects/nesspy_analysis/src/nesspy_analysis/fitting.py:79: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(lorentzian, xdata, ydata, p0=[x0, width, max_val], maxfev=10000)
# /Users/moritzobenauer/Projects/nesspy_analysis/src/nesspy_analysis/fitting.py:79: OptimizeWarning: Covariance of the parameters could not be estimated
# ...

# %%
import nesspy_analysis as npa
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

n_bootstrap = 15
n_samples = 10

fig, ax = plt.subplots(figsize=(8, 6))
ax.set_title(r"Scheme 3 $\Delta \mu = \Delta \mu \exp(-(N_R+N_B))$")
ax2 = ax.twinx()

base_path = Path("/Volumes/2025/research_nov_2025_data/SL_F0_SCHEME_3_D1_K1_GROWTH")
analysis_2 = npa.DynamicalOrderDisorder("dmu1", base_path)
analysis_2.analysis(
    bootstrap=True, n_bootstrap=n_bootstrap, type="growth_speed", n_samples=n_samples
)

results_fit_speed = analysis_2.growth_speed_fit_results
analysis_2.analysis(bootstrap=False, type="full")
mu_discrete = analysis_2.data["mu"]
m_discrete = analysis_2.data["m"]
analysis_2.analysis(
    bootstrap=True, n_bootstrap=n_bootstrap, type="mu", n_samples=n_samples
)
mus = analysis_2.mu_fit_results["mu_cont"]

thermo = npa.Thermos(jhom=-3.5, jhet=-2.0, beta=1.0, fres=0.0, k=1.0, dmu=1.0)

dphis = npa.calculate_dphi(mus, thermo, drivetype="SCHEME_3")
fit = analysis_2.mu_fit_results["lorentzian_fit"]
dphis_discrete = npa.calculate_dphi(mu_discrete, thermo, drivetype="SCHEME_3")
ax.plot(dphis_discrete, m_discrete, label="dmu1", ls="--", ms=5, marker="o")

phi_crit = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"], thermo, drivetype="SCHEME_3"
)
phi_crit_upper_lim = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"] + analysis_2.mu_fit_results["mu_c_std"],
    thermo,
    drivetype="SCHEME_3",
)
phi_crit_lower_lim = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"] - analysis_2.mu_fit_results["mu_c_std"],
    thermo,
    drivetype="SCHEME_3",
)

ax.axvline(phi_crit, linestyle="--", linewidth=1.5, label=r"$\phi_{crit}$")
ax.axvspan(phi_crit_lower_lim, phi_crit_upper_lim, alpha=0.2, label=r"$\pm\sigma$")


base_path = Path("/Volumes/2025/research_nov_2025_data/SL_F0_SCHEME_3_D2_K1_GROWTH")
analysis_2 = npa.DynamicalOrderDisorder("dmu2", base_path)
analysis_2.analysis(
    bootstrap=True, n_bootstrap=n_bootstrap, type="growth_speed", n_samples=n_samples
)

results_fit_speed = analysis_2.growth_speed_fit_results
analysis_2.analysis(bootstrap=False, type="full")
mu_discrete = analysis_2.data["mu"]
m_discrete = analysis_2.data["m"]
analysis_2.analysis(
    bootstrap=True, n_bootstrap=n_bootstrap, type="mu", n_samples=n_samples
)
mus = analysis_2.mu_fit_results["mu_cont"]

thermo = npa.Thermos(jhom=-3.5, jhet=-2.0, beta=1.0, fres=0.0, k=1.0, dmu=2.0)

dphis = npa.calculate_dphi(mus, thermo, drivetype="SCHEME_3")
fit = analysis_2.mu_fit_results["lorentzian_fit"]
dphis_discrete = npa.calculate_dphi(mu_discrete, thermo, drivetype="SCHEME_3")
ax.plot(dphis_discrete, m_discrete, label="dmu2", ls="--", ms=5, marker="o")
# ax2.plot(dphis,analysis_2.mu_fit_results['lorentzian_fit'])

phi_crit = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"], thermo, drivetype="SCHEME_3"
)
phi_crit_upper_lim = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"] + analysis_2.mu_fit_results["mu_c_std"],
    thermo,
    drivetype="SCHEME_3",
)
phi_crit_lower_lim = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"] - analysis_2.mu_fit_results["mu_c_std"],
    thermo,
    drivetype="SCHEME_3",
)

ax.axvline(phi_crit, linestyle="--", linewidth=1.5, label=r"$\phi_{crit}$")
ax.axvspan(phi_crit_lower_lim, phi_crit_upper_lim, alpha=0.2, label=r"$\pm\sigma$")


base_path = Path("/Volumes/2025/research_nov_2025_data/SL_F0_SCHEME_3_D4_K1_GROWTH")
analysis_2 = npa.DynamicalOrderDisorder("dmu4", base_path)
analysis_2.analysis(
    bootstrap=True, n_bootstrap=n_bootstrap, type="growth_speed", n_samples=n_samples
)

results_fit_speed = analysis_2.growth_speed_fit_results
analysis_2.analysis(bootstrap=False, type="full")
mu_discrete = analysis_2.data["mu"]
m_discrete = analysis_2.data["m"]
analysis_2.analysis(
    bootstrap=True, n_bootstrap=n_bootstrap, type="mu", n_samples=n_samples
)
mus = analysis_2.mu_fit_results["mu_cont"]

thermo = npa.Thermos(jhom=-3.5, jhet=-2.0, beta=1.0, fres=0.0, k=1.0, dmu=4.0)

dphis = npa.calculate_dphi(mus, thermo, drivetype="SCHEME_3")
fit = analysis_2.mu_fit_results["lorentzian_fit"]
dphis_discrete = npa.calculate_dphi(mu_discrete, thermo, drivetype="SCHEME_3")
ax.plot(dphis_discrete, m_discrete, label="dmu4", ls="--", ms=5, marker="o")
# ax2.plot(dphis,analysis_2.mu_fit_results['lorentzian_fit'])

phi_crit = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"], thermo, drivetype="SCHEME_3"
)
phi_crit_upper_lim = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"] + analysis_2.mu_fit_results["mu_c_std"],
    thermo,
    drivetype="SCHEME_3",
)
phi_crit_lower_lim = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"] - analysis_2.mu_fit_results["mu_c_std"],
    thermo,
    drivetype="SCHEME_3",
)

ax.axvline(phi_crit, linestyle="--", linewidth=1.5, label=r"$\phi_{crit}$")
ax.axvspan(phi_crit_lower_lim, phi_crit_upper_lim, alpha=0.2, label=r"$\pm\sigma$")

ax.set_xlabel(r"$V^{-1} \beta \Delta \phi$")
ax.set_ylabel(r"$m$")
ax.set_xlim(0, 1.3)
ax.legend()
# Out:
# Initialized DynamicalOrderDisorder analysis for dmu1
# /Users/moritzobenauer/Projects/nesspy_analysis/src/nesspy_analysis/fitting.py:79: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(lorentzian, xdata, ydata, p0=[x0, width, max_val], maxfev=10000)
# /Users/moritzobenauer/Projects/nesspy_analysis/src/nesspy_analysis/fitting.py:79: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(lorentzian, xdata, ydata, p0=[x0, width, max_val], maxfev=10000)
# /Users/moritzobenauer/Projects/nesspy_analysis/src/nesspy_analysis/fitting.py:79: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(lorentzian, xdata, ydata, p0=[x0, width, max_val], maxfev=10000)
# /Users/moritzobenauer/Projects/nesspy_analysis/src/nesspy_analysis/fitting.py:79: OptimizeWarning: Covariance of the parameters could not be estimated
# ...

# %%
import nesspy_analysis as npa
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

n_bootstrap = 15
n_samples = 0.8

fig, ax = plt.subplots(figsize=(8, 6))
ax.set_title(r"Scheme 6 $\Delta \mu = \Delta \mu \exp(-\vert N_R-N_B\vert)$")
ax2 = ax.twinx()

base_path = Path("/Volumes/2025/research_nov_2025_data/SL_F0_SCHEME_6_D1_K1_GROWTH")
analysis_2 = npa.DynamicalOrderDisorder("dmu1", base_path)
analysis_2.analysis(
    bootstrap=True, n_bootstrap=n_bootstrap, type="growth_speed", n_samples=n_samples
)

results_fit_speed = analysis_2.growth_speed_fit_results
analysis_2.analysis(bootstrap=False, type="full")
mu_discrete = analysis_2.data["mu"]
m_discrete = analysis_2.data["m"]
analysis_2.analysis(
    bootstrap=True, n_bootstrap=n_bootstrap, type="mu", n_samples=n_samples
)
mus = analysis_2.mu_fit_results["mu_cont"]

thermo = npa.Thermos(jhom=-3.5, jhet=-2.0, beta=1.0, fres=0.0, k=1.0, dmu=1.0)

dphis = npa.calculate_dphi(mus, thermo, drivetype="SCHEME_6")
fit = analysis_2.mu_fit_results["lorentzian_fit"]
dphis_discrete = npa.calculate_dphi(mu_discrete, thermo, drivetype="SCHEME_6")
ax.plot(dphis_discrete, m_discrete, label="dmu1", ls="--", ms=5, marker="o")

phi_crit = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"], thermo, drivetype="SCHEME_6"
)
phi_crit_upper_lim = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"] + analysis_2.mu_fit_results["mu_c_std"],
    thermo,
    drivetype="SCHEME_6",
)
phi_crit_lower_lim = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"] - analysis_2.mu_fit_results["mu_c_std"],
    thermo,
    drivetype="SCHEME_6",
)

ax.axvline(phi_crit, linestyle="--", linewidth=1.5, label=r"$\phi_{crit}$")
ax.axvspan(phi_crit_lower_lim, phi_crit_upper_lim, alpha=0.2, label=r"$\pm\sigma$")


base_path = Path("/Volumes/2025/research_nov_2025_data/SL_F0_SCHEME_6_D2_K1_GROWTH")
analysis_2 = npa.DynamicalOrderDisorder("dmu2", base_path)
analysis_2.analysis(
    bootstrap=True, n_bootstrap=n_bootstrap, type="growth_speed", n_samples=n_samples
)

results_fit_speed = analysis_2.growth_speed_fit_results
analysis_2.analysis(bootstrap=False, type="full")
mu_discrete = analysis_2.data["mu"]
m_discrete = analysis_2.data["m"]
analysis_2.analysis(
    bootstrap=True, n_bootstrap=n_bootstrap, type="mu", n_samples=n_samples
)
mus = analysis_2.mu_fit_results["mu_cont"]

thermo = npa.Thermos(jhom=-3.5, jhet=-2.0, beta=1.0, fres=0.0, k=1.0, dmu=2.0)

dphis = npa.calculate_dphi(mus, thermo, drivetype="SCHEME_6")
fit = analysis_2.mu_fit_results["lorentzian_fit"]
dphis_discrete = npa.calculate_dphi(mu_discrete, thermo, drivetype="SCHEME_6")
ax.plot(dphis_discrete, m_discrete, label="dmu2", ls="--", ms=5, marker="o")
# ax2.plot(dphis,analysis_2.mu_fit_results['lorentzian_fit'])

phi_crit = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"], thermo, drivetype="SCHEME_6"
)
phi_crit_upper_lim = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"] + analysis_2.mu_fit_results["mu_c_std"],
    thermo,
    drivetype="SCHEME_6",
)
phi_crit_lower_lim = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"] - analysis_2.mu_fit_results["mu_c_std"],
    thermo,
    drivetype="SCHEME_6",
)

ax.axvline(phi_crit, linestyle="--", linewidth=1.5, label=r"$\phi_{crit}$")
ax.axvspan(phi_crit_lower_lim, phi_crit_upper_lim, alpha=0.2, label=r"$\pm\sigma$")


base_path = Path("/Volumes/2025/research_nov_2025_data/SL_F0_SCHEME_6_D4_K1_GROWTH")
analysis_2 = npa.DynamicalOrderDisorder("dmu4", base_path)
analysis_2.analysis(
    bootstrap=True, n_bootstrap=n_bootstrap, type="growth_speed", n_samples=n_samples
)

results_fit_speed = analysis_2.growth_speed_fit_results
analysis_2.analysis(bootstrap=False, type="full")
mu_discrete = analysis_2.data["mu"]
m_discrete = analysis_2.data["m"]
analysis_2.analysis(
    bootstrap=True, n_bootstrap=n_bootstrap, type="mu", n_samples=n_samples
)
mus = analysis_2.mu_fit_results["mu_cont"]

thermo = npa.Thermos(jhom=-3.5, jhet=-2.0, beta=1.0, fres=0.0, k=1.0, dmu=4.0)

dphis = npa.calculate_dphi(mus, thermo, drivetype="SCHEME_6")
fit = analysis_2.mu_fit_results["lorentzian_fit"]
dphis_discrete = npa.calculate_dphi(mu_discrete, thermo, drivetype="SCHEME_6")
ax.plot(dphis_discrete, m_discrete, label="dmu4", ls="--", ms=5, marker="o")
# ax2.plot(dphis,analysis_2.mu_fit_results['lorentzian_fit'])

phi_crit = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"], thermo, drivetype="SCHEME_6"
)
phi_crit_upper_lim = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"] + analysis_2.mu_fit_results["mu_c_std"],
    thermo,
    drivetype="SCHEME_6",
)
phi_crit_lower_lim = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"] - analysis_2.mu_fit_results["mu_c_std"],
    thermo,
    drivetype="SCHEME_6",
)

ax.axvline(phi_crit, linestyle="--", linewidth=1.5, label=r"$\phi_{crit}$")
ax.axvspan(phi_crit_lower_lim, phi_crit_upper_lim, alpha=0.2, label=r"$\pm\sigma$")


base_path = Path("/Volumes/2025/research_nov_2025_data/ML_F0_D4_K1_SCHEME_6")
analysis = npa.DynamicalOrderDisorder("dmu4_2", base_path)

analysis.analysis(bootstrap=False, type="full")
mu_discrete = analysis.data["mu"]
m_discrete = analysis.data["m"]
analysis.analysis(
    bootstrap=True, n_bootstrap=n_bootstrap, type="mu", n_samples=n_samples
)
mus = analysis.mu_fit_results["mu_cont"]

thermo = npa.Thermos(jhom=-3.5, jhet=-2.0, beta=1.0, fres=0.0, k=1.0, dmu=4.0)

dphis = npa.calculate_dphi(mus, thermo, drivetype="SCHEME_6")
fit = analysis.mu_fit_results["lorentzian_fit"]
dphis_discrete = npa.calculate_dphi(mu_discrete, thermo, drivetype="SCHEME_6")
ax.plot(dphis_discrete, m_discrete, label="dmu4_2", ls="--", ms=5, marker="o")




base_path = Path("/Volumes/2025/research_nov_2025_data/SL_F0_SCHEME_6_D5_K1_GROWTH")
analysis_2 = npa.DynamicalOrderDisorder("dmu5", base_path)

analysis_2.analysis(bootstrap=False, type="full")
mu_discrete = analysis_2.data["mu"]
m_discrete = analysis_2.data["m"]
analysis_2.analysis(
    bootstrap=True, n_bootstrap=n_bootstrap, type="mu", n_samples=n_samples
)
mus = analysis_2.mu_fit_results["mu_cont"]

thermo = npa.Thermos(jhom=-3.5, jhet=-2.0, beta=1.0, fres=0.0, k=1.0, dmu=5.0)

dphis = npa.calculate_dphi(mus, thermo, drivetype="SCHEME_6")
fit = analysis_2.mu_fit_results["lorentzian_fit"]
dphis_discrete = npa.calculate_dphi(mu_discrete, thermo, drivetype="SCHEME_6")
ax.plot(dphis_discrete, m_discrete, label="dmu5", ls="--", ms=5, marker="o")

ax.set_xlabel(r"$V^{-1} \beta \Delta \phi$")
ax.set_ylabel(r"$m$")
ax.set_xlim(0, 2.0)
ax.legend()
# Out:
# Initialized DynamicalOrderDisorder analysis for dmu1
# /Users/moritzobenauer/Projects/nesspy_analysis/src/nesspy_analysis/fitting.py:79: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(lorentzian, xdata, ydata, p0=[x0, width, max_val], maxfev=10000)
# /Users/moritzobenauer/Projects/nesspy_analysis/src/nesspy_analysis/fitting.py:79: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(lorentzian, xdata, ydata, p0=[x0, width, max_val], maxfev=10000)
# /Users/moritzobenauer/Projects/nesspy_analysis/src/nesspy_analysis/fitting.py:79: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(lorentzian, xdata, ydata, p0=[x0, width, max_val], maxfev=10000)
# /Users/moritzobenauer/Projects/nesspy_analysis/src/nesspy_analysis/fitting.py:79: OptimizeWarning: Covariance of the parameters could not be estimated
# ...

# %%
import nesspy_analysis as npa
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

n_bootstrap = 25
n_samples = 10

fig, ax = plt.subplots(figsize=(8, 6))
ax.set_title(r"Scheme 93 $k = k_0 \exp(-\vert N_R-N_B\vert)$")
ax2 = ax.twinx()


base_path = Path("/Volumes/2025/research_nov_2025_data/SL_F0_SCHEME_93_D6_K10_GROWTH")
analysis_2 = npa.DynamicalOrderDisorder("dmu6", base_path)

analysis_2.analysis(bootstrap=False, type="full")
mu_discrete = analysis_2.data["mu"]
m_discrete = analysis_2.data["m"]
analysis_2.analysis(
    bootstrap=True, n_bootstrap=n_bootstrap, type="mu", n_samples=n_samples
)
mus = analysis_2.mu_fit_results["mu_cont"]
print(analysis_2.calculate_zero_growth_speed())

thermo = npa.Thermos(jhom=-3.5, jhet=-2.0, beta=1.0, fres=0.0, k=10.0, dmu=6.0)

dphis = npa.calculate_dphi(mus, thermo, drivetype="SCHEME_93")
fit = analysis_2.mu_fit_results["lorentzian_fit"]
dphis_discrete = npa.calculate_dphi(mu_discrete, thermo, drivetype="SCHEME_93")
ax.plot(dphis_discrete, m_discrete, label="dmu6", ls="--", ms=5, marker="o")

phi_crit = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"], thermo, drivetype="SCHEME_93"
)
phi_crit_upper_lim = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"] + analysis_2.mu_fit_results["mu_c_std"],
    thermo,
    drivetype="SCHEME_93",
)
phi_crit_lower_lim = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"] - analysis_2.mu_fit_results["mu_c_std"],
    thermo,
    drivetype="SCHEME_93",
)

ax.axvline(phi_crit, linestyle="--", linewidth=1.5, label=r"$\phi_{crit}$")
ax.axvspan(phi_crit_lower_lim, phi_crit_upper_lim, alpha=0.2, label=r"$\pm\sigma$")

base_path = Path("/Volumes/2025/research_nov_2025_data/SL_F0_SCHEME_93_D4_K10_GROWTH")
analysis_2 = npa.DynamicalOrderDisorder("dmu4", base_path)
analysis_2.analysis(
    bootstrap=True, n_bootstrap=n_bootstrap, type="growth_speed", n_samples=n_samples
)

results_fit_speed = analysis_2.growth_speed_fit_results
analysis_2.analysis(bootstrap=False, type="full")
mu_discrete = analysis_2.data["mu"]
m_discrete = analysis_2.data["m"]
analysis_2.analysis(
    bootstrap=True, n_bootstrap=n_bootstrap, type="mu", n_samples=n_samples
)
mus = analysis_2.mu_fit_results["mu_cont"]

thermo = npa.Thermos(jhom=-3.5, jhet=-2.0, beta=1.0, fres=0.0, k=10.0, dmu=4.0)

dphis = npa.calculate_dphi(mus, thermo, drivetype="SCHEME_93")
fit = analysis_2.mu_fit_results["lorentzian_fit"]
dphis_discrete = npa.calculate_dphi(mu_discrete, thermo, drivetype="SCHEME_93")
ax.plot(dphis_discrete, m_discrete, label="dmu4", ls="--", ms=5, marker="o")

phi_crit = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"], thermo, drivetype="SCHEME_93"
)
phi_crit_upper_lim = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"] + analysis_2.mu_fit_results["mu_c_std"],
    thermo,
    drivetype="SCHEME_93",
)
phi_crit_lower_lim = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"] - analysis_2.mu_fit_results["mu_c_std"],
    thermo,
    drivetype="SCHEME_93",
)

ax.axvline(phi_crit, linestyle="--", linewidth=1.5, label=r"$\phi_{crit}$")
ax.axvspan(phi_crit_lower_lim, phi_crit_upper_lim, alpha=0.2, label=r"$\pm\sigma$")

base_path = Path("/Volumes/2025/research_nov_2025_data/SL_F0_SCHEME_93_D3_K10_GROWTH")
analysis_2 = npa.DynamicalOrderDisorder("dmu3", base_path)

analysis_2.analysis(bootstrap=False, type="full")
mu_discrete = analysis_2.data["mu"]
m_discrete = analysis_2.data["m"]
analysis_2.analysis(
    bootstrap=True, n_bootstrap=n_bootstrap, type="mu", n_samples=n_samples
)
mus = analysis_2.mu_fit_results["mu_cont"]

thermo = npa.Thermos(jhom=-3.5, jhet=-2.0, beta=1.0, fres=0.0, k=10.0, dmu=3.0)


print(analysis_2.calculate_zero_growth_speed())
dphis = npa.calculate_dphi(mus, thermo, drivetype="SCHEME_93")
fit = analysis_2.mu_fit_results["lorentzian_fit"]
dphis_discrete = npa.calculate_dphi(mu_discrete, thermo, drivetype="SCHEME_93")
ax.plot(dphis_discrete, m_discrete, label="dmu3", ls="--", ms=5, marker="o")

phi_crit = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"], thermo, drivetype="SCHEME_93"
)
phi_crit_upper_lim = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"] + analysis_2.mu_fit_results["mu_c_std"],
    thermo,
    drivetype="SCHEME_93",
)
phi_crit_lower_lim = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"] - analysis_2.mu_fit_results["mu_c_std"],
    thermo,
    drivetype="SCHEME_93",
)

ax.axvline(phi_crit, linestyle="--", linewidth=1.5, label=r"$\phi_{crit}$")
ax.axvspan(phi_crit_lower_lim, phi_crit_upper_lim, alpha=0.2, label=r"$\pm\sigma$")


ax.set_xlabel(r"$V^{-1} \beta \Delta \phi$")
ax.set_ylabel(r"$m$")
ax.set_xlim(0, 1.3)
ax.legend()
# Out:
# Initialized DynamicalOrderDisorder analysis for dmu6
# /Users/moritzobenauer/Projects/nesspy_analysis/src/nesspy_analysis/fitting.py:79: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(lorentzian, xdata, ydata, p0=[x0, width, max_val], maxfev=10000)
# /Users/moritzobenauer/Projects/nesspy_analysis/src/nesspy_analysis/fitting.py:79: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(lorentzian, xdata, ydata, p0=[x0, width, max_val], maxfev=10000)
# /Users/moritzobenauer/Projects/nesspy_analysis/src/nesspy_analysis/fitting.py:79: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(lorentzian, xdata, ydata, p0=[x0, width, max_val], maxfev=10000)
# /Users/moritzobenauer/Projects/nesspy_analysis/src/nesspy_analysis/fitting.py:79: OptimizeWarning: Covariance of the parameters could not be estimated
# ...

# %%
import nesspy_analysis as npa
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

n_bootstrap = 15
n_samples = 8

fig, ax = plt.subplots(figsize=(8, 6))
ax.set_title(r"Scheme 91 $k = k_0 \exp(-(N_R+N_B))$")
ax2 = ax.twinx()


base_path = Path("/Volumes/2025/research_nov_2025_data/SL_F0_SCHEME_91_D0_K1_GROWTH")
analysis_2 = npa.DynamicalOrderDisorder("dmu0", base_path)

analysis_2.analysis(bootstrap=False, type="full")
mu_discrete = analysis_2.data["mu"]
m_discrete = analysis_2.data["m"]
analysis_2.analysis(
    bootstrap=True, n_bootstrap=n_bootstrap, type="mu", n_samples=n_samples
)
mus = analysis_2.mu_fit_results["mu_cont"]

thermo = npa.Thermos(jhom=-3.5, jhet=-2.0, beta=1.0, fres=0.0, k=1.0, dmu=0.0)

dphis = npa.calculate_dphi(mus, thermo, drivetype="SCHEME_91")
fit = analysis_2.mu_fit_results["lorentzian_fit"]
dphis_discrete = npa.calculate_dphi(mu_discrete, thermo, drivetype="SCHEME_91")
ax.plot(dphis_discrete, m_discrete, label="dmu0", ls="--", ms=5, marker="o")

phi_crit = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"], thermo, drivetype="SCHEME_91"
)
phi_crit_upper_lim = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"] + analysis_2.mu_fit_results["mu_c_std"],
    thermo,
    drivetype="SCHEME_91",
)
phi_crit_lower_lim = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"] - analysis_2.mu_fit_results["mu_c_std"],
    thermo,
    drivetype="SCHEME_91",
)

ax.axvline(phi_crit, linestyle="--", linewidth=1.5, label=r"$\phi_{crit}$")
ax.axvspan(phi_crit_lower_lim, phi_crit_upper_lim, alpha=0.2, label=r"$\pm\sigma$")


base_path = Path("/Volumes/2025/research_nov_2025_data/SL_F0_SCHEME_91_D1_K1_GROWTH")
analysis_2 = npa.DynamicalOrderDisorder("dmu1", base_path)

analysis_2.analysis(bootstrap=False, type="full")
mu_discrete = analysis_2.data["mu"]
m_discrete = analysis_2.data["m"]
analysis_2.analysis(
    bootstrap=True, n_bootstrap=n_bootstrap, type="mu", n_samples=n_samples
)
mus = analysis_2.mu_fit_results["mu_cont"]

thermo = npa.Thermos(jhom=-3.5, jhet=-2.0, beta=1.0, fres=0.0, k=1.0, dmu=1.0)

dphis = npa.calculate_dphi(mus, thermo, drivetype="SCHEME_91")
fit = analysis_2.mu_fit_results["lorentzian_fit"]
dphis_discrete = npa.calculate_dphi(mu_discrete, thermo, drivetype="SCHEME_91")
ax.plot(dphis_discrete, m_discrete, label="dmu1", ls="--", ms=5, marker="o")

phi_crit = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"], thermo, drivetype="SCHEME_91"
)
phi_crit_upper_lim = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"] + analysis_2.mu_fit_results["mu_c_std"],
    thermo,
    drivetype="SCHEME_91",
)
phi_crit_lower_lim = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"] - analysis_2.mu_fit_results["mu_c_std"],
    thermo,
    drivetype="SCHEME_91",
)

ax.axvline(phi_crit, linestyle="--", linewidth=1.5, label=r"$\phi_{crit}$")
ax.axvspan(phi_crit_lower_lim, phi_crit_upper_lim, alpha=0.2, label=r"$\pm\sigma$")

base_path = Path("/Volumes/2025/research_nov_2025_data/SL_F0_SCHEME_91_D2_K1_GROWTH")
analysis_2 = npa.DynamicalOrderDisorder("dmu2", base_path)

analysis_2.analysis(bootstrap=False, type="full")
mu_discrete = analysis_2.data["mu"]
m_discrete = analysis_2.data["m"]
analysis_2.analysis(
    bootstrap=True, n_bootstrap=n_bootstrap, type="mu", n_samples=n_samples
)
mus = analysis_2.mu_fit_results["mu_cont"]

thermo = npa.Thermos(jhom=-3.5, jhet=-2.0, beta=1.0, fres=0.0, k=1.0, dmu=2.0)

dphis = npa.calculate_dphi(mus, thermo, drivetype="SCHEME_91")
fit = analysis_2.mu_fit_results["lorentzian_fit"]
dphis_discrete = npa.calculate_dphi(mu_discrete, thermo, drivetype="SCHEME_91")
ax.plot(dphis_discrete, m_discrete, label="dmu2", ls="--", ms=5, marker="o")

phi_crit = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"], thermo, drivetype="SCHEME_91"
)
phi_crit_upper_lim = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"] + analysis_2.mu_fit_results["mu_c_std"],
    thermo,
    drivetype="SCHEME_91",
)
phi_crit_lower_lim = npa.calculate_dphi(
    analysis_2.mu_fit_results["mu_c_mean"] - analysis_2.mu_fit_results["mu_c_std"],
    thermo,
    drivetype="SCHEME_91",
)

ax.axvline(phi_crit, linestyle="--", linewidth=1.5, label=r"$\phi_{crit}$")
ax.axvspan(phi_crit_lower_lim, phi_crit_upper_lim, alpha=0.2, label=r"$\pm\sigma$")


ax.set_xlabel(r"$V^{-1} \beta \Delta \phi$")
ax.set_ylabel(r"$m$")
ax.set_xlim(0, 1.3)
ax.legend()
# Out:
# Initialized DynamicalOrderDisorder analysis for dmu0
# /Users/moritzobenauer/Projects/nesspy_analysis/src/nesspy_analysis/fitting.py:79: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(lorentzian, xdata, ydata, p0=[x0, width, max_val], maxfev=10000)
# /Users/moritzobenauer/Projects/nesspy_analysis/src/nesspy_analysis/fitting.py:79: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(lorentzian, xdata, ydata, p0=[x0, width, max_val], maxfev=10000)
# /Users/moritzobenauer/Projects/nesspy_analysis/src/nesspy_analysis/fitting.py:79: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt, pcov = curve_fit(lorentzian, xdata, ydata, p0=[x0, width, max_val], maxfev=10000)
# /Users/moritzobenauer/Projects/nesspy_analysis/src/nesspy_analysis/fitting.py:79: OptimizeWarning: Covariance of the parameters could not be estimated
# ...

# %%
import nesspy_analysis as npa
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

n_bootstrap = 2
n_samples = 0.8

fig, ax = plt.subplots(figsize=(8, 6))
ax2 = ax.twinx()


base_path = Path("/Volumes/2025/research_nov_2025_data/ML_F-20_D0_K0")
analysis_2 = npa.DynamicalOrderDisorder("no_inert_states", base_path)

analysis_2.analysis(bootstrap=False, type="full")
mu_discrete = analysis_2.data["mu"]
m_discrete = analysis_2.data["m"]
susc = analysis_2.data["susc"]
# analysis_2.analysis(
#     bootstrap=True, n_bootstrap=n_bootstrap, type="mu", n_samples=n_samples
# )
# mus = analysis_2.mu_fit_results["mu_cont"]
# fit = analysis_2.mu_fit_results["lorentzian_fit"]

thermo = npa.Thermos(jhom=-3.5, jhet=-2.0, beta=1.0, fres=-20.0, k=0.0, dmu=0.0)

dphis = npa.calculate_dphi(mus, thermo, drivetype="NODRIVE")
# fit = analysis_2.mu_fit_results["lorentzian_fit"]
dphis_discrete = npa.calculate_dphi(mu_discrete, thermo, drivetype="NODRIVE")


# ax.plot(dphis, fit, label="no_inert_states", ls="--", ms=5, marker="o")
ax.plot(dphis_discrete, m_discrete, label="no_inert_states_data", ls="--", ms=5, marker="o")

# print(analysis_2.mu_fit_results["mu_c_mean"], analysis_2.mu_fit_results["mu_c_std"])


base_path = Path("/Volumes/2025/research_nov_2025_data/ML_F0_D0_K1")
analysis_3 = npa.DynamicalOrderDisorder("inert_states", base_path)

analysis_3.analysis(bootstrap=False, type="full")
mu_discrete = analysis_3.data["mu"]
m_discrete = analysis_3.data["m"]
susc = analysis_3.data["susc"]
# analysis_3.analysis(
#     bootstrap=True, n_bootstrap=n_bootstrap, type="mu", n_samples=n_samples
# )
# mus = analysis_3.mu_fit_results["mu_cont"]
# fit = analysis_3.mu_fit_results["lorentzian_fit"]

thermo = npa.Thermos(jhom=-3.5, jhet=-2.0, beta=1.0, fres=0.0, k=1.0, dmu=0.0)

dphis = npa.calculate_dphi(mus, thermo, drivetype="NODRIVE")
# fit = analysis_3.mu_fit_results["lorentzian_fit"]
dphis_discrete = npa.calculate_dphi(mu_discrete, thermo, drivetype="NODRIVE")

# ax.plot(dphis, fit, label="no_inert_states", ls="--", ms=5, marker="o")
ax.plot(dphis_discrete, m_discrete, label="no_inert_states_data", ls="--", ms=5, marker="o")

# print(analysis_3.mu_fit_results["mu_c_mean"], analysis_3.mu_fit_results["mu_c_std"])



base_path = Path("/Volumes/2025/research_nov_2025_data/ML_F0_D4_K1_SCHEME_6")
analysis_4 = npa.DynamicalOrderDisorder("scheme6", base_path)

analysis_4.analysis(bootstrap=False, type="full")
mu_discrete = analysis_4.data["mu"]
m_discrete = analysis_4.data["m"]
susc = analysis_4.data["susc"]
analysis_4.analysis(
    bootstrap=True, n_bootstrap=n_bootstrap, type="mu", n_samples=n_samples
)
mus = analysis_4.mu_fit_results["mu_cont"]
fit = analysis_4.mu_fit_results["lorentzian_fit"]

thermo = npa.Thermos(jhom=-3.5, jhet=-2.0, beta=1.0, fres=0.0, k=1.0, dmu=4.0)

dphis = npa.calculate_dphi(mus, thermo, drivetype="SCHEME_6")
fit = analysis_4.mu_fit_results["lorentzian_fit"]
dphis_discrete = npa.calculate_dphi(mu_discrete, thermo, drivetype="SCHEME_6")

# ax.plot(dphis, fit, label="scheme6", ls="--", ms=5, marker="o")
ax.plot(dphis_discrete, m_discrete, label="scheme6_data", ls="--", ms=5, marker="o")

print(analysis_4.mu_fit_results["mu_c_mean"], analysis_4.mu_fit_results["mu_c_std"])
# Out:
# Initialized DynamicalOrderDisorder analysis for no_inert_states
# Initialized DynamicalOrderDisorder analysis for inert_states
# Initialized DynamicalOrderDisorder analysis for scheme6
# -4.402004351968654 0.019489535443026895

# %%
import nesspy_analysis as npa
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

n_bootstrap = 45
n_samples = 0.8

fig, ax = plt.subplots(figsize=(8, 6))
ax2 = ax.twinx()


base_path = Path("/Volumes/2025/research_nov_2025_data/ML_F-20_D0_K0")
analysis_2 = npa.DynamicalOrderDisorder("no_inert_states", base_path)

analysis_2.analysis(bootstrap=False, type="full")
mu_discrete = analysis_2.data["mu"]
m_discrete = analysis_2.data["m"]
susc = analysis_2.data["susc"]
analysis_2.analysis(
    bootstrap=True, n_bootstrap=n_bootstrap, type="growth_speed", n_samples=n_samples
)

growth_speeds = analysis_2.growth_speed_fit_results["growth_speed_cont"]
fit = analysis_2.growth_speed_fit_results["lorentzian_fit"]
ax.plot(growth_speeds, fit, label="no_inert_states", ls="--", ms=5, marker="o")





base_path = Path("/Volumes/2025/research_nov_2025_data/ML_F0_D0_K1")
analysis_3 = npa.DynamicalOrderDisorder("inert_states", base_path)

analysis_3.analysis(bootstrap=False, type="full")
mu_discrete = analysis_3.data["mu"]
m_discrete = analysis_3.data["m"]
susc = analysis_3.data["susc"]
analysis_3.analysis(
    bootstrap=True, n_bootstrap=n_bootstrap, type="growth_speed", n_samples=n_samples
)

growth_speeds = analysis_3.growth_speed_fit_results["growth_speed_cont"]
fit = analysis_3.growth_speed_fit_results["lorentzian_fit"]


ax.plot(growth_speeds, fit, label="no_inert_states", ls="--", ms=5, marker="o")

ax.set_xscale("log")
# Out:
# Initialized DynamicalOrderDisorder analysis for no_inert_states
# Initialized DynamicalOrderDisorder analysis for inert_states

# %%
import seaborn as sns

df = pd.read_csv('/Volumes/2025/research_nov_2025_data/ML_F-20_D0_K0/-6.85/out.csv', comment='#')
df2 = pd.read_csv('/Volumes/2025/research_nov_2025_data/ML_F-20_D0_K0/-6.8/out.csv', comment='#')

# sns.kdeplot(data=df, x='m')
sns.histplot(data=df, x='m', bins=100, stat='density', alpha=0.3)
sns.histplot(data=df2, x='m', bins=100, stat='density', alpha=0.3)

sns.kdeplot(data=df, x='m', bw_adjust=0.5)
sns.kdeplot(data=df2, x='m', bw_adjust=0.5)

plt.plot()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 3
#       1 import seaborn as sns
# ----> 3 df = pd.read_csv('/Volumes/2025/research_nov_2025_data/ML_F-20_D0_K0/-6.85/out.csv', comment='#')
#       4 df2 = pd.read_csv('/Volumes/2025/research_nov_2025_data/ML_F-20_D0_K0/-6.8/out.csv', comment='#')
#       6 # sns.kdeplot(data=df, x='m')
#
# ...

# %%
u = np.load("/Users/moritzobenauer/Downloads/savestate_lattice_384400000.npy")
plt.imshow(u, origin='lower', cmap='viridis')

# %%
import nesspy_analysis as npa
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


base_path = Path("/Users/moritzobenauer/Desktop/ML_F-20_D0_K0")
analysis_2 = npa.DynamicalOrderDisorder("no_inert_states", base_path)
thermos_for_inert = npa.Thermos()

data = analysis_2.get_data()
data = data.sort_values(by=["mu"])

data["dphi"] = npa.calculate_dphi(data["mu"], thermos_for_inert)

plt.errorbar(
    data['dphi'],
    data["m"],
    yerr=data["dm"],
    label="No Inert States",
    fmt="o",
)


base_path = Path("/Volumes/2025/research_nov_2025_data/ML_F0_D2_K1_SCHEME_7")
analysis_2 = npa.DynamicalOrderDisorder("scheme7", base_path)
thermos_for_s7 = npa.Thermos(method="SCHEME_7", fres=0.0, k=1.0, dmu=2.0)

data = analysis_2.get_data()
data = data.sort_values(by=["mu"])

data["dphi"] = npa.calculate_dphi(data["mu"], thermos_for_s7)

plt.errorbar(
    data['dphi'],
    data["m"],
    yerr=data["dm"],
    label="Scheme 7 d2",
    fmt="o",
)

base_path = Path("/Volumes/2025/research_nov_2025_data/ML_F0_D1_K1_SCHEME_7")
analysis_2 = npa.DynamicalOrderDisorder("scheme7", base_path)
thermos_for_s7 = npa.Thermos(method="SCHEME_7", fres=0.0, k=1.0, dmu=1.0)

data = analysis_2.get_data()
data = data.sort_values(by=["mu"])

data["dphi"] = npa.calculate_dphi(data["mu"], thermos_for_s7)

plt.errorbar(
    data['dphi'],
    data["m"],
    yerr=data["dm"],
    label="Scheme 7 d1",
    fmt="o",
)

plt.legend()
plt.grid()
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/moritzobenauer/miniforge3/envs/nesspy/lib/python3.13/logging/__init__.py", line 1151, in emit
#     msg = self.format(record)
#   File "/Users/moritzobenauer/miniforge3/envs/nesspy/lib/python3.13/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ~~~~~~~~~~^^^^^^^^
#   File "/Users/moritzobenauer/miniforge3/envs/nesspy/lib/python3.13/logging/__init__.py", line 712, in format
#     record.message = record.getMessage()
#                      ~~~~~~~~~~~~~~~~~^^
#   File "/Users/moritzobenauer/miniforge3/envs/nesspy/lib/python3.13/logging/__init__.py", line 400, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
# ...

# %%
lattice = np.load("/Volumes/2025/research_nov_2025_data/ML_F0_D1_K1_SCHEME_7/-6.65/2025-11-13-14:24_4/lattice_final.npy")
npa.plot_lattice_clean(lattice)
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)
